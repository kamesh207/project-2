# %% [markdown]
# <a href="https://colab.research.google.com/github/kamesh207/project-2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Stock Price Prediction with LSTM (File already uploaded in Colab)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# 1. Load the already uploaded Excel file (edit the name if needed)
filename = "sample_historical_stock_data.xlsx"  # <-- Change this to your file name if different
data = pd.read_excel(filename, index_col=0)

# 2. Check for 'Close' column
if 'Close' not in data.columns:
    raise ValueError("The Excel file must contain a 'Close' column.")

# 3. Preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['Close']])

# 4. Create sequences
def create_dataset(dataset, time_step=60):
    X, y = [], []
    for i in range(time_step, len(dataset)):
        X.append(dataset[i - time_step:i, 0])
        y.append(dataset[i, 0])
    return np.array(X), np.array(y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# 5. Train/test split
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# 6. Build and train the LSTM model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X.shape[1], 1)),
    LSTM(50),
    Dense(1)
])
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=20, batch_size=32, verbose=1)

# 7. Predictions
predictions = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predictions)
actual_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# 8. Save predictions to Excel
results_df = pd.DataFrame({
    'Actual Price': actual_prices.flatten(),
    'Predicted Price': predicted_prices.flatten()
})
results_df.to_excel("stock_price_predictions.xlsx", index=False)

# 9. Plot results
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.6119
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.4807
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.3657
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.2635
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.1724
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0937
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0335
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0038
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0186
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0580
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0710
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0556
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0316
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0131
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0043
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0036
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0075
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0129
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0177
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0207
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
